# %%
# Pandas is a library that provides useful data structure and data analysis tools
# pandas is well suited for many different kinds of data
# . Tabular data with heterogeneously-typed columns, as in an SQL table or Excel spreadsheet
# . Ordered and unordered (not necessarily fixed-frequency) time series data.
# . Arbitrary matrix data (homogeneously typed or heterogeneous) with row and column labels
# . Any other form of observational / statistical data sets. The data actually need not be labeled 
#   at all to be placed into a pandas data structure. 

import numpy as np
import pandas as pd

# %%
# Pandas Data Structure

# %%
# . Series
#   . One dimension array capable of holding any data type,
# . To create Series
data = np.array([1,2,3,4])
index = np.array(['a','b','c','d'])
s = pd.Series(data, index=index)
print(s)
# . The "data" can be list, tuple, dict, numpy.ndarray ...
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
s = pd.Series([1,2,3,4])
print(s)
print('')
x = {'a':0, 'b':1} # x is dictionary
s = pd.Series(x)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
#
# a    0
# b    1
# dtype: int64

# %%
# . The index should be the same size with the data
s = pd.Series([0,1,2,3], index = ['a','b','c','d'])
print(s)
# Out:
# a    0
# b    1
# c    2
# d    3
# dtype: int64

# %%
# . You can access the series element by their index
print(s['b'])
print('')
S = set()
S.add('a')
S.add('c')
print(s[S])
# Out:
# 1
#
# c    2
# a    0
# dtype: int64

# %%
# . Data frame
#  . 2-dimensional labeled data structure with columns of poetentially different types
#  . like a spreadsheet or SQL table, or a dict of Series objects
#  . accepts many different kinds of input:
#    . Dict of 1D ndarrays, lists, dicts, or Series
#    . 2-D numpy.ndarray
#    . Structured or record ndarry
#    . A Series
#    . Another DataFrame

# %%
# From dict of series or dict
d = {}
d['a'] = pd.Series([1,2,3,4], index = ['a','b','c','d'])
d['b'] = pd.Series([5,6,7,8], index = ['c','a','b','x'])
df = pd.DataFrame(d)
print(df)
# Out:
#      a    b
# a  1.0  6.0
# b  2.0  7.0
# c  3.0  5.0
# d  4.0  NaN
# x  NaN  8.0

# %%
# The index and column parameter
df = pd.DataFrame(d, index = ['a','b','c'])
print(df)
print('')
df = pd.DataFrame(d, index = ['a','b','c'], columns = ['a','d'])
print(df)
# Out:
#    a  b
# a  1  6
# b  2  7
# c  3  5
#
#    a    d
# a  1  NaN
# b  2  NaN
# c  3  NaN

# %%
# From list of dict
x = [{'a':1, 'b':2}, {'a':3, 'b':4, 'c':5}]
print(pd.DataFrame(x))
print('')
print(pd.DataFrame(x, index = ['first','second']))
print('')
print(pd.DataFrame(x, index = ['first','second'], columns=['a','c']))
print('')
# Out:
#    a  b    c
# 0  1  2  NaN
# 1  3  4  5.0
#
#         a  b    c
# first   1  2  NaN
# second  3  4  5.0
#
#         a    c
# first   1  NaN
# second  3  5.0

# %%
# Read data
# . However, most of the time the data issotred in the file.
# . Pandas provides convenient functions to read data.
# . pandas.read_csv()
# . For example, if we have data like
csv_filename = 'Metadata_Country_API.csv'
pd.read_csv(csv_filename)
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Upper middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# 13           AZE       Europe & Central Asia  Upper middle income
# 14           BDI          Sub-Saharan Africa           Low income
# 15           BEL       Europe & Central Asia          High income
# 16           BEN          Sub-Saharan Africa           Low income
# 17           BFA          Sub-Saharan Africa           Low income
# 18           BGD                  South Asia  Lower middle income
# 19           BGR       Europe & Central Asia  Upper middle income
# 20           BHR  Middle East & North Africa          High income
# 21           BHS   Latin America & Caribbean          High income
# 22           BIH       Europe & Central Asia  Upper middle income
# 23           BLR       Europe & Central Asia  Upper middle income
# 24           BLZ   Latin America & Caribbean  Upper middle income
# 25           BMU               North America          High income
# 26           BOL   Latin America & Caribbean  Lower middle income
# 27           BRA   Latin America & Caribbean  Upper middle income
# 28           BRB   Latin America & Caribbean          High income
# 29           BRN         East Asia & Pacific          High income
# ..           ...                         ...                  ...
# 233          TLA                         NaN                  NaN
# 234          TLS         East Asia & Pacific  Lower middle income
# 235          TMN                         NaN                  NaN
# 236          TON         East Asia & Pacific  Upper middle income
# 237          TSA                         NaN                  NaN
# 238          TSS                         NaN                  NaN
# 239          TTO   Latin America & Caribbean          High income
# 240          TUN  Middle East & North Africa  Lower middle income
# 241          TUR       Europe & Central Asia  Upper middle income
# 242          TUV         East Asia & Pacific  Upper middle income
# 243          TZA          Sub-Saharan Africa           Low income
# 244          UGA          Sub-Saharan Africa           Low income
# 245          UKR       Europe & Central Asia  Lower middle income
# 246          UMC                         NaN                  NaN
# 247          URY   Latin America & Caribbean          High income
# 248          USA               North America          High income
# 249          UZB       Europe & Central Asia  Lower middle income
# 250          VCT   Latin America & Caribbean  Upper middle income
# 251          VEN   Latin America & Caribbean  Upper middle income
# 252          VGB   Latin America & Caribbean          High income
# 253          VIR   Latin America & Caribbean          High income
# 254          VNM         East Asia & Pacific  Lower middle income
# 255          VUT         East Asia & Pacific  Lower middle income
# 256          WLD                         NaN                  NaN
# 257          WSM         East Asia & Pacific  Upper middle income
# 258          XKX       Europe & Central Asia  Upper middle income
# 259          YEM  Middle East & North Africa           Low income
# 260          ZAF          Sub-Saharan Africa  Upper middle income
# 261          ZMB          Sub-Saharan Africa  Lower middle income
# 262          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5    Arab World aggregate. Arab World is composed o...
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11   Fiscal year end: June 30; reporting period for...
# 12   A simple multiplier is used to convert the nat...
# 13                                                 NaN
# 14                                                 NaN
# 15   A simple multiplier is used to convert the nat...
# 16                                                 NaN
# 17                                                 NaN
# 18   Fiscal year end: June 30; reporting period for...
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23   Data before 2015 were adjusted to reflect the ...
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 233  Latin America & the Caribbean (IDA & IBRD coun...
# 234                                                NaN
# 235  Middle East & North Africa (IDA & IBRD countri...
# 236                                                NaN
# 237       South Asia (IDA & IBRD countries) aggregate.
# 238  Sub-Saharan Africa (IDA & IBRD countries) aggr...
# 239                                                NaN
# 240                                                NaN
# 241                                                NaN
# 242                                                NaN
# 243                                                NaN
# 244  Fiscal year end: June 30; reporting period for...
# 245                                                NaN
# 246  Upper middle income group aggregate. Upper-mid...
# 247                                                NaN
# 248                                                NaN
# 249                                                NaN
# 250                                                NaN
# 251                                                NaN
# 252                                                NaN
# 253                                                NaN
# 254                                                NaN
# 255                                                NaN
# 256                                   World aggregate.
# 257  Fiscal year ends on June 30; reporting period ...
# 258                                                NaN
# 259                                                NaN
# 260  Fiscal year end: March 31; reporting period fo...
# 261  National accounts data were rebased to reflect...
# 262                                                NaN
#
#                                    TableName  Unnamed: 5
# 0                                      Aruba         NaN
# 1                                Afghanistan         NaN
# 2                                     Angola         NaN
# 3                                    Albania         NaN
# 4                                    Andorra         NaN
# 5                                 Arab World         NaN
# 6                       United Arab Emirates         NaN
# 7                                  Argentina         NaN
# 8                                    Armenia         NaN
# 9                             American Samoa         NaN
# 10                       Antigua and Barbuda         NaN
# 11                                 Australia         NaN
# 12                                   Austria         NaN
# 13                                Azerbaijan         NaN
# 14                                   Burundi         NaN
# 15                                   Belgium         NaN
# 16                                     Benin         NaN
# 17                              Burkina Faso         NaN
# 18                                Bangladesh         NaN
# 19                                  Bulgaria         NaN
# 20                                   Bahrain         NaN
# 21                              Bahamas, The         NaN
# 22                    Bosnia and Herzegovina         NaN
# 23                                   Belarus         NaN
# 24                                    Belize         NaN
# 25                                   Bermuda         NaN
# 26                                   Bolivia         NaN
# 27                                    Brazil         NaN
# 28                                  Barbados         NaN
# 29                         Brunei Darussalam         NaN
# ..                                       ...         ...
# 233   Latin America & Caribbean (IDA & IBRD)         NaN
# 234                              Timor-Leste         NaN
# 235  Middle East & North Africa (IDA & IBRD)         NaN
# 236                                    Tonga         NaN
# 237                  South Asia (IDA & IBRD)         NaN
# 238          Sub-Saharan Africa (IDA & IBRD)         NaN
# 239                      Trinidad and Tobago         NaN
# 240                                  Tunisia         NaN
# 241                                   Turkey         NaN
# 242                                   Tuvalu         NaN
# 243                                 Tanzania         NaN
# 244                                   Uganda         NaN
# 245                                  Ukraine         NaN
# 246                      Upper middle income         NaN
# 247                                  Uruguay         NaN
# 248                            United States         NaN
# 249                               Uzbekistan         NaN
# 250           St. Vincent and the Grenadines         NaN
# 251                            Venezuela, RB         NaN
# 252                   British Virgin Islands         NaN
# 253                    Virgin Islands (U.S.)         NaN
# 254                                  Vietnam         NaN
# 255                                  Vanuatu         NaN
# 256                                    World         NaN
# 257                                    Samoa         NaN
# 258                                   Kosovo         NaN
# 259                              Yemen, Rep.         NaN
# 260                             South Africa         NaN
# 261                                   Zambia         NaN
# 262                                 Zimbabwe         NaN
#
# [263 rows x 6 columns]

# %%
pd.read_csv(csv_filename, index_col = 0)
# Out:
#                                   Region          IncomeGroup  \
# Country Code
# ABW            Latin America & Caribbean          High income
# AFG                           South Asia           Low income
# AGO                   Sub-Saharan Africa  Lower middle income
# ALB                Europe & Central Asia  Upper middle income
# AND                Europe & Central Asia          High income
# ARB                                  NaN                  NaN
# ARE           Middle East & North Africa          High income
# ARG            Latin America & Caribbean  Upper middle income
# ARM                Europe & Central Asia  Upper middle income
# ASM                  East Asia & Pacific  Upper middle income
# ATG            Latin America & Caribbean          High income
# AUS                  East Asia & Pacific          High income
# AUT                Europe & Central Asia          High income
# AZE                Europe & Central Asia  Upper middle income
# BDI                   Sub-Saharan Africa           Low income
# BEL                Europe & Central Asia          High income
# BEN                   Sub-Saharan Africa           Low income
# BFA                   Sub-Saharan Africa           Low income
# BGD                           South Asia  Lower middle income
# BGR                Europe & Central Asia  Upper middle income
# BHR           Middle East & North Africa          High income
# BHS            Latin America & Caribbean          High income
# BIH                Europe & Central Asia  Upper middle income
# BLR                Europe & Central Asia  Upper middle income
# BLZ            Latin America & Caribbean  Upper middle income
# BMU                        North America          High income
# BOL            Latin America & Caribbean  Lower middle income
# BRA            Latin America & Caribbean  Upper middle income
# BRB            Latin America & Caribbean          High income
# BRN                  East Asia & Pacific          High income
# ...                                  ...                  ...
# TLA                                  NaN                  NaN
# TLS                  East Asia & Pacific  Lower middle income
# TMN                                  NaN                  NaN
# TON                  East Asia & Pacific  Upper middle income
# TSA                                  NaN                  NaN
# TSS                                  NaN                  NaN
# TTO            Latin America & Caribbean          High income
# TUN           Middle East & North Africa  Lower middle income
# TUR                Europe & Central Asia  Upper middle income
# TUV                  East Asia & Pacific  Upper middle income
# TZA                   Sub-Saharan Africa           Low income
# UGA                   Sub-Saharan Africa           Low income
# UKR                Europe & Central Asia  Lower middle income
# UMC                                  NaN                  NaN
# URY            Latin America & Caribbean          High income
# USA                        North America          High income
# UZB                Europe & Central Asia  Lower middle income
# VCT            Latin America & Caribbean  Upper middle income
# VEN            Latin America & Caribbean  Upper middle income
# VGB            Latin America & Caribbean          High income
# VIR            Latin America & Caribbean          High income
# VNM                  East Asia & Pacific  Lower middle income
# VUT                  East Asia & Pacific  Lower middle income
# WLD                                  NaN                  NaN
# WSM                  East Asia & Pacific  Upper middle income
# XKX                Europe & Central Asia  Upper middle income
# YEM           Middle East & North Africa           Low income
# ZAF                   Sub-Saharan Africa  Upper middle income
# ZMB                   Sub-Saharan Africa  Lower middle income
# ZWE                   Sub-Saharan Africa  Lower middle income
#
#                                                    SpecialNotes  \
# Country Code
# ABW                                                         NaN
# AFG                                                         NaN
# AGO                                                         NaN
# ALB                                                         NaN
# AND                                                         NaN
# ARB           Arab World aggregate. Arab World is composed o...
# ARE                                                         NaN
# ARG                                                         NaN
# ARM                                                         NaN
# ASM                                                         NaN
# ATG                                                         NaN
# AUS           Fiscal year end: June 30; reporting period for...
# AUT           A simple multiplier is used to convert the nat...
# AZE                                                         NaN
# BDI                                                         NaN
# BEL           A simple multiplier is used to convert the nat...
# BEN                                                         NaN
# BFA                                                         NaN
# BGD           Fiscal year end: June 30; reporting period for...
# BGR                                                         NaN
# BHR                                                         NaN
# BHS                                                         NaN
# BIH                                                         NaN
# BLR           Data before 2015 were adjusted to reflect the ...
# BLZ                                                         NaN
# BMU                                                         NaN
# BOL                                                         NaN
# BRA                                                         NaN
# BRB                                                         NaN
# BRN                                                         NaN
# ...                                                         ...
# TLA           Latin America & the Caribbean (IDA & IBRD coun...
# TLS                                                         NaN
# TMN           Middle East & North Africa (IDA & IBRD countri...
# TON                                                         NaN
# TSA                South Asia (IDA & IBRD countries) aggregate.
# TSS           Sub-Saharan Africa (IDA & IBRD countries) aggr...
# TTO                                                         NaN
# TUN                                                         NaN
# TUR                                                         NaN
# TUV                                                         NaN
# TZA                                                         NaN
# UGA           Fiscal year end: June 30; reporting period for...
# UKR                                                         NaN
# UMC           Upper middle income group aggregate. Upper-mid...
# URY                                                         NaN
# USA                                                         NaN
# UZB                                                         NaN
# VCT                                                         NaN
# VEN                                                         NaN
# VGB                                                         NaN
# VIR                                                         NaN
# VNM                                                         NaN
# VUT                                                         NaN
# WLD                                            World aggregate.
# WSM           Fiscal year ends on June 30; reporting period ...
# XKX                                                         NaN
# YEM                                                         NaN
# ZAF           Fiscal year end: March 31; reporting period fo...
# ZMB           National accounts data were rebased to reflect...
# ZWE                                                         NaN
#
#                                             TableName  Unnamed: 5
# Country Code
# ABW                                             Aruba         NaN
# AFG                                       Afghanistan         NaN
# AGO                                            Angola         NaN
# ALB                                           Albania         NaN
# AND                                           Andorra         NaN
# ARB                                        Arab World         NaN
# ARE                              United Arab Emirates         NaN
# ARG                                         Argentina         NaN
# ARM                                           Armenia         NaN
# ASM                                    American Samoa         NaN
# ATG                               Antigua and Barbuda         NaN
# AUS                                         Australia         NaN
# AUT                                           Austria         NaN
# AZE                                        Azerbaijan         NaN
# BDI                                           Burundi         NaN
# BEL                                           Belgium         NaN
# BEN                                             Benin         NaN
# BFA                                      Burkina Faso         NaN
# BGD                                        Bangladesh         NaN
# BGR                                          Bulgaria         NaN
# BHR                                           Bahrain         NaN
# BHS                                      Bahamas, The         NaN
# BIH                            Bosnia and Herzegovina         NaN
# BLR                                           Belarus         NaN
# BLZ                                            Belize         NaN
# BMU                                           Bermuda         NaN
# BOL                                           Bolivia         NaN
# BRA                                            Brazil         NaN
# BRB                                          Barbados         NaN
# BRN                                 Brunei Darussalam         NaN
# ...                                               ...         ...
# TLA            Latin America & Caribbean (IDA & IBRD)         NaN
# TLS                                       Timor-Leste         NaN
# TMN           Middle East & North Africa (IDA & IBRD)         NaN
# TON                                             Tonga         NaN
# TSA                           South Asia (IDA & IBRD)         NaN
# TSS                   Sub-Saharan Africa (IDA & IBRD)         NaN
# TTO                               Trinidad and Tobago         NaN
# TUN                                           Tunisia         NaN
# TUR                                            Turkey         NaN
# TUV                                            Tuvalu         NaN
# TZA                                          Tanzania         NaN
# UGA                                            Uganda         NaN
# UKR                                           Ukraine         NaN
# UMC                               Upper middle income         NaN
# URY                                           Uruguay         NaN
# USA                                     United States         NaN
# UZB                                        Uzbekistan         NaN
# VCT                    St. Vincent and the Grenadines         NaN
# VEN                                     Venezuela, RB         NaN
# VGB                            British Virgin Islands         NaN
# VIR                             Virgin Islands (U.S.)         NaN
# VNM                                           Vietnam         NaN
# VUT                                           Vanuatu         NaN
# WLD                                             World         NaN
# WSM                                             Samoa         NaN
# XKX                                            Kosovo         NaN
# YEM                                       Yemen, Rep.         NaN
# ZAF                                      South Africa         NaN
# ZMB                                            Zambia         NaN
# ZWE                                          Zimbabwe         NaN
#
# [263 rows x 5 columns]

# %%
df= pd.read_csv(csv_filename)
print(type(df))

print(df['Country Code'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 0      ABW
# 1      AFG
# 2      AGO
# 3      ALB
# 4      AND
# 5      ARB
# 6      ARE
# 7      ARG
# 8      ARM
# 9      ASM
# 10     ATG
# 11     AUS
# 12     AUT
# 13     AZE
# 14     BDI
# 15     BEL
# 16     BEN
# 17     BFA
# 18     BGD
# 19     BGR
# 20     BHR
# 21     BHS
# 22     BIH
# 23     BLR
# 24     BLZ
# 25     BMU
# 26     BOL
# 27     BRA
# 28     BRB
# 29     BRN
#       ...
# 233    TLA
# 234    TLS
# 235    TMN
# 236    TON
# 237    TSA
# 238    TSS
# 239    TTO
# 240    TUN
# 241    TUR
# 242    TUV
# 243    TZA
# 244    UGA
# 245    UKR
# 246    UMC
# 247    URY
# 248    USA
# 249    UZB
# 250    VCT
# 251    VEN
# 252    VGB
# 253    VIR
# 254    VNM
# 255    VUT
# 256    WLD
# 257    WSM
# 258    XKX
# 259    YEM
# 260    ZAF
# 261    ZMB
# 262    ZWE
# Name: Country Code, Length: 263, dtype: object

# %%
# Access elements

# %%
csv_filename = 'Metadata_Country_API.csv'
pd.read_csv(csv_filename, index_col=2)
# Out:
#                     Country Code                      Region  \
# IncomeGroup
# High income                  ABW   Latin America & Caribbean
# Low income                   AFG                  South Asia
# Lower middle income          AGO          Sub-Saharan Africa
# Upper middle income          ALB       Europe & Central Asia
# High income                  AND       Europe & Central Asia
# NaN                          ARB                         NaN
# High income                  ARE  Middle East & North Africa
# Upper middle income          ARG   Latin America & Caribbean
# Upper middle income          ARM       Europe & Central Asia
# Upper middle income          ASM         East Asia & Pacific
# High income                  ATG   Latin America & Caribbean
# High income                  AUS         East Asia & Pacific
# High income                  AUT       Europe & Central Asia
# Upper middle income          AZE       Europe & Central Asia
# Low income                   BDI          Sub-Saharan Africa
# High income                  BEL       Europe & Central Asia
# Low income                   BEN          Sub-Saharan Africa
# Low income                   BFA          Sub-Saharan Africa
# Lower middle income          BGD                  South Asia
# Upper middle income          BGR       Europe & Central Asia
# High income                  BHR  Middle East & North Africa
# High income                  BHS   Latin America & Caribbean
# Upper middle income          BIH       Europe & Central Asia
# Upper middle income          BLR       Europe & Central Asia
# Upper middle income          BLZ   Latin America & Caribbean
# High income                  BMU               North America
# Lower middle income          BOL   Latin America & Caribbean
# Upper middle income          BRA   Latin America & Caribbean
# High income                  BRB   Latin America & Caribbean
# High income                  BRN         East Asia & Pacific
# ...                          ...                         ...
# NaN                          TLA                         NaN
# Lower middle income          TLS         East Asia & Pacific
# NaN                          TMN                         NaN
# Upper middle income          TON         East Asia & Pacific
# NaN                          TSA                         NaN
# NaN                          TSS                         NaN
# High income                  TTO   Latin America & Caribbean
# Lower middle income          TUN  Middle East & North Africa
# Upper middle income          TUR       Europe & Central Asia
# Upper middle income          TUV         East Asia & Pacific
# Low income                   TZA          Sub-Saharan Africa
# Low income                   UGA          Sub-Saharan Africa
# Lower middle income          UKR       Europe & Central Asia
# NaN                          UMC                         NaN
# High income                  URY   Latin America & Caribbean
# High income                  USA               North America
# Lower middle income          UZB       Europe & Central Asia
# Upper middle income          VCT   Latin America & Caribbean
# Upper middle income          VEN   Latin America & Caribbean
# High income                  VGB   Latin America & Caribbean
# High income                  VIR   Latin America & Caribbean
# Lower middle income          VNM         East Asia & Pacific
# Lower middle income          VUT         East Asia & Pacific
# NaN                          WLD                         NaN
# Upper middle income          WSM         East Asia & Pacific
# Upper middle income          XKX       Europe & Central Asia
# Low income                   YEM  Middle East & North Africa
# Upper middle income          ZAF          Sub-Saharan Africa
# Lower middle income          ZMB          Sub-Saharan Africa
# Lower middle income          ZWE          Sub-Saharan Africa
#
#                                                           SpecialNotes  \
# IncomeGroup
# High income                                                        NaN
# Low income                                                         NaN
# Lower middle income                                                NaN
# Upper middle income                                                NaN
# High income                                                        NaN
# NaN                  Arab World aggregate. Arab World is composed o...
# High income                                                        NaN
# Upper middle income                                                NaN
# Upper middle income                                                NaN
# Upper middle income                                                NaN
# High income                                                        NaN
# High income          Fiscal year end: June 30; reporting period for...
# High income          A simple multiplier is used to convert the nat...
# Upper middle income                                                NaN
# Low income                                                         NaN
# High income          A simple multiplier is used to convert the nat...
# Low income                                                         NaN
# Low income                                                         NaN
# Lower middle income  Fiscal year end: June 30; reporting period for...
# Upper middle income                                                NaN
# High income                                                        NaN
# High income                                                        NaN
# Upper middle income                                                NaN
# Upper middle income  Data before 2015 were adjusted to reflect the ...
# Upper middle income                                                NaN
# High income                                                        NaN
# Lower middle income                                                NaN
# Upper middle income                                                NaN
# High income                                                        NaN
# High income                                                        NaN
# ...                                                                ...
# NaN                  Latin America & the Caribbean (IDA & IBRD coun...
# Lower middle income                                                NaN
# NaN                  Middle East & North Africa (IDA & IBRD countri...
# Upper middle income                                                NaN
# NaN                       South Asia (IDA & IBRD countries) aggregate.
# NaN                  Sub-Saharan Africa (IDA & IBRD countries) aggr...
# High income                                                        NaN
# Lower middle income                                                NaN
# Upper middle income                                                NaN
# Upper middle income                                                NaN
# Low income                                                         NaN
# Low income           Fiscal year end: June 30; reporting period for...
# Lower middle income                                                NaN
# NaN                  Upper middle income group aggregate. Upper-mid...
# High income                                                        NaN
# High income                                                        NaN
# Lower middle income                                                NaN
# Upper middle income                                                NaN
# Upper middle income                                                NaN
# High income                                                        NaN
# High income                                                        NaN
# Lower middle income                                                NaN
# Lower middle income                                                NaN
# NaN                                                   World aggregate.
# Upper middle income  Fiscal year ends on June 30; reporting period ...
# Upper middle income                                                NaN
# Low income                                                         NaN
# Upper middle income  Fiscal year end: March 31; reporting period fo...
# Lower middle income  National accounts data were rebased to reflect...
# Lower middle income                                                NaN
#
#                                                    TableName  Unnamed: 5
# IncomeGroup
# High income                                            Aruba         NaN
# Low income                                       Afghanistan         NaN
# Lower middle income                                   Angola         NaN
# Upper middle income                                  Albania         NaN
# High income                                          Andorra         NaN
# NaN                                               Arab World         NaN
# High income                             United Arab Emirates         NaN
# Upper middle income                                Argentina         NaN
# Upper middle income                                  Armenia         NaN
# Upper middle income                           American Samoa         NaN
# High income                              Antigua and Barbuda         NaN
# High income                                        Australia         NaN
# High income                                          Austria         NaN
# Upper middle income                               Azerbaijan         NaN
# Low income                                           Burundi         NaN
# High income                                          Belgium         NaN
# Low income                                             Benin         NaN
# Low income                                      Burkina Faso         NaN
# Lower middle income                               Bangladesh         NaN
# Upper middle income                                 Bulgaria         NaN
# High income                                          Bahrain         NaN
# High income                                     Bahamas, The         NaN
# Upper middle income                   Bosnia and Herzegovina         NaN
# Upper middle income                                  Belarus         NaN
# Upper middle income                                   Belize         NaN
# High income                                          Bermuda         NaN
# Lower middle income                                  Bolivia         NaN
# Upper middle income                                   Brazil         NaN
# High income                                         Barbados         NaN
# High income                                Brunei Darussalam         NaN
# ...                                                      ...         ...
# NaN                   Latin America & Caribbean (IDA & IBRD)         NaN
# Lower middle income                              Timor-Leste         NaN
# NaN                  Middle East & North Africa (IDA & IBRD)         NaN
# Upper middle income                                    Tonga         NaN
# NaN                                  South Asia (IDA & IBRD)         NaN
# NaN                          Sub-Saharan Africa (IDA & IBRD)         NaN
# High income                              Trinidad and Tobago         NaN
# Lower middle income                                  Tunisia         NaN
# Upper middle income                                   Turkey         NaN
# Upper middle income                                   Tuvalu         NaN
# Low income                                          Tanzania         NaN
# Low income                                            Uganda         NaN
# Lower middle income                                  Ukraine         NaN
# NaN                                      Upper middle income         NaN
# High income                                          Uruguay         NaN
# High income                                    United States         NaN
# Lower middle income                               Uzbekistan         NaN
# Upper middle income           St. Vincent and the Grenadines         NaN
# Upper middle income                            Venezuela, RB         NaN
# High income                           British Virgin Islands         NaN
# High income                            Virgin Islands (U.S.)         NaN
# Lower middle income                                  Vietnam         NaN
# Lower middle income                                  Vanuatu         NaN
# NaN                                                    World         NaN
# Upper middle income                                    Samoa         NaN
# Upper middle income                                   Kosovo         NaN
# Low income                                       Yemen, Rep.         NaN
# Upper middle income                             South Africa         NaN
# Lower middle income                                   Zambia         NaN
# Lower middle income                                 Zimbabwe         NaN
#
# [263 rows x 5 columns]

# %%
csv_filename = 'Metadata_Country_API.csv'
pd.read_csv(csv_filename, index_col=2)['Region']['Low income']
# you want to show Region where IncomeGroup = 'Low income'
# set index_col = 2 to index IncomeGroup field. 
# Then get Region values where IncomeGroup='Low income' by something['Region']['Low income']
# Out:
# Low income                    South Asia
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income     Latin America & Caribbean
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income                    South Asia
# Low income           East Asia & Pacific
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income    Middle East & North Africa
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income         Europe & Central Asia
# Low income            Sub-Saharan Africa
# Low income            Sub-Saharan Africa
# Low income    Middle East & North Africa
# Name: Region, dtype: object

# %%
# . You can also access the rows with
csv_filename = 'Metadata_Country_API.csv'
pd.read_csv(csv_filename, index_col=2)[:3] # get row0, row1,row2
# Out:
#                     Country Code                     Region SpecialNotes  \
# IncomeGroup
# High income                  ABW  Latin America & Caribbean          NaN
# Low income                   AFG                 South Asia          NaN
# Lower middle income          AGO         Sub-Saharan Africa          NaN
#
#                        TableName  Unnamed: 5
# IncomeGroup
# High income                Aruba         NaN
# Low income           Afghanistan         NaN
# Lower middle income       Angola         NaN

# %%
# Find the most common value

# %%
# . Now we use a relatively large dataset to show the power of pandas.
# . The dataset can be  obtained at 
#   https://data.cityofnewyork.us/dataset/311-Service-Requests-From-2015/57g5-etyj
# . It's the record of service request from the NYC 311 from year of 2015 to now
# . You can try to open it with excel, and this is what you get
# Download address : https://drive.google.com/open?id=1nnQDV1ogUlZUnm_AsN4n5NzBkDfL5Iwh
# Or you can use 311_Service_Requests_from_2010_to_Present_Short.csv (it is short version)

# %%
csv_filename = '311_Service_Requests_from_2010_to_Present_Short.csv'
pd.read_csv(csv_filename, index_col=2)[:3] # get row0, row1,row2
# Out:
#                         Unique Key            Created Date Agency  \
# Closed Date
# 05/24/2015 09:55:00 AM    30688456  05/24/2015 09:02:00 AM    DOT
# 03/09/2018 11:10:00 PM    38676721  03/12/2018 09:56:00 AM    DOT
# 05/24/2015 08:20:00 PM    30688451  05/24/2015 07:00:00 PM    DOT
#
#                                          Agency Name  \
# Closed Date
# 05/24/2015 09:55:00 AM  Department of Transportation
# 03/09/2018 11:10:00 PM  Department of Transportation
# 05/24/2015 08:20:00 PM  Department of Transportation
#
#                                   Complaint Type        Descriptor  \
# Closed Date
# 05/24/2015 09:55:00 AM  Traffic Signal Condition   Veh Signal Head
# 03/09/2018 11:10:00 PM    Street Light Condition  Street Light Out
# 05/24/2015 08:20:00 PM  Traffic Signal Condition        Controller
#
#                        Location Type Incident Zip Incident Address  \
# Closed Date
# 05/24/2015 09:55:00 AM           NaN          NaN              NaN
# 03/09/2018 11:10:00 PM           NaN          NaN              NaN
# 05/24/2015 08:20:00 PM           NaN          NaN              NaN
#
#                        Street Name       ...        Road Ramp  \
# Closed Date                              ...
# 05/24/2015 09:55:00 AM         NaN       ...              NaN
# 03/09/2018 11:10:00 PM         NaN       ...              NaN
# 05/24/2015 08:20:00 PM         NaN       ...              NaN
#
#                        Bridge Highway Segment Latitude Longitude Location  \
# Closed Date
# 05/24/2015 09:55:00 AM                    NaN      NaN       NaN      NaN
# 03/09/2018 11:10:00 PM                    NaN      NaN       NaN      NaN
# 05/24/2015 08:20:00 PM                    NaN      NaN       NaN      NaN
#
#                        Zip Codes  Community Districts Borough Boundaries  \
# Closed Date
# 05/24/2015 09:55:00 AM       NaN                  NaN                NaN
# 03/09/2018 11:10:00 PM       NaN                  NaN                NaN
# 05/24/2015 08:20:00 PM       NaN                  NaN                NaN
#
#                        City Council Districts Police Precincts
# Closed Date
# 05/24/2015 09:55:00 AM                    NaN              NaN
# 03/09/2018 11:10:00 PM                    NaN              NaN
# 05/24/2015 08:20:00 PM                    NaN              NaN
#
# [3 rows x 45 columns]

# %%
csv_filename = '311_Service_Requests_from_2010_to_Present_Short.csv'
df = pd.read_csv(csv_filename, index_col=2)
df['Complaint Type'].value_counts()[:10]
# Out:
# Street Light Condition            2019
# Traffic Signal Condition          1003
# HPD Literature Request             199
# Street Condition                   134
# Water System                        85
# Sanitation Condition                83
# Sewer                               78
# Maintenance or Facility             64
# Noise                               57
# DOF Property - Reduction Issue      47
# Name: Complaint Type, dtype: int64

# %%
# . We can even plot it directly
import matplotlib.pyplot as plt
df['Complaint Type'].value_counts()[:10].plot(kind = 'bar')
plt.show()

# %%
# . Select only certain type of data
#   . What if we want only the noise complaints ?
noise_complaint = df[df['Complaint Type'] == 'Noise - Street/Sidewalk']
print(noise_complaint.shape)
# Out:
# (2, 45)

# %%
noise_complaint[:3]
# Out:
#                         Unique Key            Created Date Agency  \
# Closed Date
# 07/29/2019 12:14:56 PM    39469576  06/15/2018 08:50:39 PM   NYPD
# 07/29/2019 12:14:55 PM    39472381  06/15/2018 08:59:50 PM   NYPD
#
#                                             Agency Name  \
# Closed Date
# 07/29/2019 12:14:56 PM  New York City Police Department
# 07/29/2019 12:14:55 PM  New York City Police Department
#
#                                  Complaint Type        Descriptor  \
# Closed Date
# 07/29/2019 12:14:56 PM  Noise - Street/Sidewalk  Loud Music/Party
# 07/29/2019 12:14:55 PM  Noise - Street/Sidewalk  Loud Music/Party
#
#                           Location Type Incident Zip  Incident Address  \
# Closed Date
# 07/29/2019 12:14:56 PM  Street/Sidewalk          NaN  WEST  166 STREET
# 07/29/2019 12:14:55 PM  Street/Sidewalk          NaN   SHERIDAN AVENUE
#
#                              Street Name       ...        Road Ramp  \
# Closed Date                                    ...
# 07/29/2019 12:14:56 PM  WEST  166 STREET       ...              NaN
# 07/29/2019 12:14:55 PM   SHERIDAN AVENUE       ...              NaN
#
#                        Bridge Highway Segment Latitude Longitude Location  \
# Closed Date
# 07/29/2019 12:14:56 PM                    NaN      NaN       NaN      NaN
# 07/29/2019 12:14:55 PM                    NaN      NaN       NaN      NaN
#
#                        Zip Codes  Community Districts Borough Boundaries  \
# Closed Date
# 07/29/2019 12:14:56 PM       NaN                  NaN                NaN
# 07/29/2019 12:14:55 PM       NaN                  NaN                NaN
#
#                        City Council Districts Police Precincts
# Closed Date
# 07/29/2019 12:14:56 PM                    NaN              NaN
# 07/29/2019 12:14:55 PM                    NaN              NaN
#
# [2 rows x 45 columns]

# %%
#   . Reset the index with pandas.DataFrame.reset_index()

# %%
# How to find the the class name without iterating through the whole data frame ?
df[:10].isnull()
# Out:
#                         Unique Key  Created Date  Agency  Agency Name  \
# Closed Date
# 05/24/2015 09:55:00 AM       False         False   False        False
# 03/09/2018 11:10:00 PM       False         False   False        False
# 05/24/2015 08:20:00 PM       False         False   False        False
# 05/26/2015 10:09:00 AM       False         False   False        False
# 04/29/2018 03:57:57 PM       False         False   False        False
# 03/13/2018 12:30:00 AM       False         False   False        False
# 05/08/2018 04:17:51 PM       False         False   False        False
# 03/12/2018 08:21:54 AM       False         False   False        False
# 04/29/2018 04:22:49 PM       False         False   False        False
# 03/20/2018 08:17:00 AM       False         False   False        False
#
#                         Complaint Type  Descriptor  Location Type  \
# Closed Date
# 05/24/2015 09:55:00 AM           False       False           True
# 03/09/2018 11:10:00 PM           False       False           True
# 05/24/2015 08:20:00 PM           False       False           True
# 05/26/2015 10:09:00 AM           False       False           True
# 04/29/2018 03:57:57 PM           False       False          False
# 03/13/2018 12:30:00 AM           False       False           True
# 05/08/2018 04:17:51 PM           False       False          False
# 03/12/2018 08:21:54 AM           False       False           True
# 04/29/2018 04:22:49 PM           False       False          False
# 03/20/2018 08:17:00 AM           False       False           True
#
#                         Incident Zip  Incident Address  Street Name  \
# Closed Date
# 05/24/2015 09:55:00 AM          True              True         True
# 03/09/2018 11:10:00 PM          True              True         True
# 05/24/2015 08:20:00 PM          True              True         True
# 05/26/2015 10:09:00 AM          True             False        False
# 04/29/2018 03:57:57 PM          True              True         True
# 03/13/2018 12:30:00 AM          True              True         True
# 05/08/2018 04:17:51 PM         False              True         True
# 03/12/2018 08:21:54 AM         False             False        False
# 04/29/2018 04:22:49 PM          True              True         True
# 03/20/2018 08:17:00 AM          True             False        False
#
#                               ...         Road Ramp  Bridge Highway Segment  \
# Closed Date                   ...
# 05/24/2015 09:55:00 AM        ...              True                    True
# 03/09/2018 11:10:00 PM        ...              True                    True
# 05/24/2015 08:20:00 PM        ...              True                    True
# 05/26/2015 10:09:00 AM        ...              True                    True
# 04/29/2018 03:57:57 PM        ...              True                    True
# 03/13/2018 12:30:00 AM        ...              True                    True
# 05/08/2018 04:17:51 PM        ...              True                    True
# 03/12/2018 08:21:54 AM        ...              True                    True
# 04/29/2018 04:22:49 PM        ...              True                    True
# 03/20/2018 08:17:00 AM        ...              True                    True
#
#                         Latitude  Longitude  Location  Zip Codes  \
# Closed Date
# 05/24/2015 09:55:00 AM      True       True      True       True
# 03/09/2018 11:10:00 PM      True       True      True       True
# 05/24/2015 08:20:00 PM      True       True      True       True
# 05/26/2015 10:09:00 AM      True       True      True       True
# 04/29/2018 03:57:57 PM      True       True      True       True
# 03/13/2018 12:30:00 AM      True       True      True       True
# 05/08/2018 04:17:51 PM      True       True      True       True
# 03/12/2018 08:21:54 AM      True       True      True       True
# 04/29/2018 04:22:49 PM      True       True      True       True
# 03/20/2018 08:17:00 AM      True       True      True       True
#
#                         Community Districts  Borough Boundaries  \
# Closed Date
# 05/24/2015 09:55:00 AM                 True                True
# 03/09/2018 11:10:00 PM                 True                True
# 05/24/2015 08:20:00 PM                 True                True
# 05/26/2015 10:09:00 AM                 True                True
# 04/29/2018 03:57:57 PM                 True                True
# 03/13/2018 12:30:00 AM                 True                True
# 05/08/2018 04:17:51 PM                 True                True
# 03/12/2018 08:21:54 AM                 True                True
# 04/29/2018 04:22:49 PM                 True                True
# 03/20/2018 08:17:00 AM                 True                True
#
#                         City Council Districts  Police Precincts
# Closed Date
# 05/24/2015 09:55:00 AM                    True              True
# 03/09/2018 11:10:00 PM                    True              True
# 05/24/2015 08:20:00 PM                    True              True
# 05/26/2015 10:09:00 AM                    True              True
# 04/29/2018 03:57:57 PM                    True              True
# 03/13/2018 12:30:00 AM                    True              True
# 05/08/2018 04:17:51 PM                    True              True
# 03/12/2018 08:21:54 AM                    True              True
# 04/29/2018 04:22:49 PM                    True              True
# 03/20/2018 08:17:00 AM                    True              True
#
# [10 rows x 45 columns]

# %%
# Use any to get whether all element is True
df[:10].isnull().any()
# Out:
# Unique Key                        False
# Created Date                      False
# Agency                            False
# Agency Name                       False
# Complaint Type                    False
# Descriptor                        False
# Location Type                      True
# Incident Zip                       True
# Incident Address                   True
# Street Name                        True
# Cross Street 1                     True
# Cross Street 2                     True
# Intersection Street 1              True
# Intersection Street 2              True
# Address Type                       True
# City                               True
# Landmark                           True
# Facility Type                      True
# Status                            False
# Due Date                           True
# Resolution Description            False
# Resolution Action Updated Date     True
# Community Board                   False
# BBL                                True
# Borough                           False
# X Coordinate (State Plane)         True
# Y Coordinate (State Plane)         True
# Open Data Channel Type            False
# Park Facility Name                False
# Park Borough                      False
# Vehicle Type                       True
# Taxi Company Borough               True
# Taxi Pick Up Location              True
# Bridge Highway Name                True
# Bridge Highway Direction           True
# Road Ramp                          True
# Bridge Highway Segment             True
# Latitude                           True
# Longitude                          True
# Location                           True
# Zip Codes                          True
# Community Districts                True
# Borough Boundaries                 True
# City Council Districts             True
# Police Precincts                   True
# dtype: bool

# %%
# The axis is wrong
# Fix with axis argument
df[:10].isnull().any(axis = 1)
# Out:
# Closed Date
# 05/24/2015 09:55:00 AM    True
# 03/09/2018 11:10:00 PM    True
# 05/24/2015 08:20:00 PM    True
# 05/26/2015 10:09:00 AM    True
# 04/29/2018 03:57:57 PM    True
# 03/13/2018 12:30:00 AM    True
# 05/08/2018 04:17:51 PM    True
# 03/12/2018 08:21:54 AM    True
# 04/29/2018 04:22:49 PM    True
# 03/20/2018 08:17:00 AM    True
# dtype: bool

# %%
# Access the data frame with index

# %%
# The iloc attribute allow you to query the data frame using integer index
csv_filename = '311_Service_Requests_from_2010_to_Present_Short.csv'
df = pd.read_csv(csv_filename)

# %%
df
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 0       30688456  05/24/2015 09:02:00 AM  05/24/2015 09:55:00 AM    DOT
# 1       38676721  03/12/2018 09:56:00 AM  03/09/2018 11:10:00 PM    DOT
# 2       30688451  05/24/2015 07:00:00 PM  05/24/2015 08:20:00 PM    DOT
# 3       30688579  05/24/2015 01:09:00 PM  05/26/2015 10:09:00 AM    DOT
# 4       39058876  04/29/2018 03:57:39 PM  04/29/2018 03:57:57 PM    HRA
# 5       38676450  03/12/2018 11:13:00 PM  03/13/2018 12:30:00 AM    DOT
# 6       39059071  04/29/2018 05:40:22 PM  05/08/2018 04:17:51 PM    DPR
# 7       38676115  03/12/2018 08:21:54 AM  03/12/2018 08:21:54 AM    DOT
# 8       39058863  04/29/2018 04:22:03 PM  04/29/2018 04:22:49 PM    HRA
# 9       38676866  03/12/2018 09:07:00 AM  03/20/2018 08:17:00 AM    DOT
# 10      38676185  03/12/2018 11:29:00 AM  07/31/2018 12:00:00 AM    DOT
# 11      39058875  04/29/2018 01:34:24 PM  04/29/2018 01:34:35 PM    HRA
# 12      39059228  04/29/2018 07:45:06 PM  04/29/2018 07:45:59 PM    HRA
# 13      38677539  03/12/2018 11:12:00 PM  03/13/2018 01:15:00 AM    DOT
# 14      38677691  03/12/2018 09:48:00 AM  03/09/2018 09:10:00 PM    DOT
# 15      39059289  04/29/2018 10:23:59 AM  04/29/2018 10:24:42 AM    HRA
# 16      30688750  05/24/2015 11:53:00 AM  06/19/2015 11:58:00 AM    DOT
# 17      39059413  04/29/2018 01:20:00 PM  04/29/2018 03:04:43 PM   NYPD
# 18      38677688  03/12/2018 11:18:00 PM  03/13/2018 12:48:00 PM    DOT
# 19      38677899  03/13/2018 12:11:00 PM  03/14/2018 01:50:00 PM    DEP
# 20      39060036  04/29/2018 03:43:14 PM  04/29/2018 04:08:20 PM    DPR
# 21      39059281  04/29/2018 03:38:41 PM  04/29/2018 03:39:27 PM    HRA
# 22      38677677  03/12/2018 11:36:00 AM  03/12/2018 11:36:00 AM    DOT
# 23      38677488  03/12/2018 11:27:00 AM  03/09/2018 11:27:00 AM    DOT
# 24      39059229  04/29/2018 03:03:59 PM  05/09/2018 05:52:15 PM    DPR
# 25      38677645  03/12/2018 11:24:00 PM  03/12/2018 11:50:00 PM    DOT
# 26      38677690  03/12/2018 09:58:00 AM  03/10/2018 12:01:00 AM    DOT
# 27      38678271  03/13/2018 04:40:00 PM  03/19/2018 09:54:00 AM    DOT
# 28      38678284  03/13/2018 10:53:00 AM  03/13/2018 10:53:00 AM    DOT
# 29      38678241  03/13/2018 03:53:00 AM  03/13/2018 04:30:00 AM    DOT
# ...          ...                     ...                     ...    ...
# 4297    30717682  05/28/2015 01:12:16 PM  06/02/2015 11:02:30 AM    HPD
# 4298    38386772  02/03/2018 02:36:36 PM  02/04/2018 12:45:00 AM    DOT
# 4299    38894467  04/09/2018 02:45:00 AM  04/09/2018 03:20:00 AM    DOT
# 4300    38894856  04/09/2018 02:13:00 PM  04/06/2018 02:13:00 PM    DOT
# 4301    41363764  01/07/2019 09:31:04 AM                     NaN   DSNY
# 4302    30717692  05/28/2015 09:34:03 AM  06/02/2015 11:01:51 AM    HPD
# 4303    38894852  04/09/2018 02:48:00 PM  04/07/2018 01:25:00 AM    DOT
# 4304    38894846  04/09/2018 10:52:00 AM  04/05/2018 11:01:00 PM    DOT
# 4305    38894204  04/09/2018 10:13:00 AM  04/05/2018 10:13:00 AM    DOT
# 4306    38386566  02/04/2018 07:16:00 PM  07/31/2018 12:00:00 AM    DOT
# 4307    38894483  04/09/2018 02:45:00 PM  04/09/2018 04:15:00 PM    DOT
# 4308    30717681  05/28/2015 01:33:54 PM  06/02/2015 11:02:28 AM    HPD
# 4309    38894876  04/09/2018 10:18:00 AM  04/09/2018 05:15:00 PM    DEP
# 4310    39020573  04/24/2018 12:30:33 PM  04/30/2018 11:27:10 AM    DOT
# 4311    38894468  04/09/2018 10:28:00 AM  04/09/2018 02:50:00 PM    DOT
# 4312    38894901  04/09/2018 07:15:00 AM  06/20/2018 01:40:00 PM    DOT
# 4313    30717693  05/28/2015 11:15:43 PM  06/02/2015 10:59:03 AM    HPD
# 4314    40001315  08/13/2018 09:27:15 AM  08/16/2018 08:09:01 AM    DOF
# 4315    38894851  04/09/2018 02:39:00 PM  04/06/2018 10:10:00 PM    DOT
# 4316    38895534  04/09/2018 02:59:00 PM  06/12/2018 09:03:00 AM    DOT
# 4317    19061943  11/05/2010 08:57:00 PM  11/06/2010 12:00:00 PM   DSNY
# 4318    40547467  10/14/2018 03:58:23 PM  10/15/2018 02:13:34 AM    DOT
# 4319    38895328  04/09/2018 10:21:00 AM  04/07/2018 12:35:00 AM    DOT
# 4320    40547387  10/14/2018 08:30:00 PM  10/14/2018 08:50:00 PM    DOT
# 4321    39022551  04/24/2018 11:54:38 AM  04/30/2018 02:21:10 PM    DOF
# 4322    39750198  07/16/2018 11:26:32 AM  08/09/2018 12:55:33 PM    DPR
# 4323    30717847  05/28/2015 03:15:00 PM  05/04/2015 03:15:00 PM    DOT
# 4324    40757271  11/06/2018 01:05:58 PM  11/08/2018 10:59:25 AM   DFTA
# 4325    38895615  04/09/2018 11:42:00 PM  04/10/2018 12:15:00 AM    DOT
# 4326    30717793  05/28/2015 11:55:29 AM  06/02/2015 11:02:25 AM    HPD
#
#                                             Agency Name  \
# 0                          Department of Transportation
# 1                          Department of Transportation
# 2                          Department of Transportation
# 3                          Department of Transportation
# 4                          HRA Benefit Card Replacement
# 5                          Department of Transportation
# 6                    Department of Parks and Recreation
# 7                          Department of Transportation
# 8                          HRA Benefit Card Replacement
# 9                          Department of Transportation
# 10                         Department of Transportation
# 11                         HRA Benefit Card Replacement
# 12                         HRA Benefit Card Replacement
# 13                         Department of Transportation
# 14                         Department of Transportation
# 15                         HRA Benefit Card Replacement
# 16                         Department of Transportation
# 17                      New York City Police Department
# 18                         Department of Transportation
# 19               Department of Environmental Protection
# 20                   Department of Parks and Recreation
# 21                         HRA Benefit Card Replacement
# 22                         Department of Transportation
# 23                         Department of Transportation
# 24                   Department of Parks and Recreation
# 25                         Department of Transportation
# 26                         Department of Transportation
# 27                         Department of Transportation
# 28                         Department of Transportation
# 29                         Department of Transportation
# ...                                                 ...
# 4297  Department of Housing Preservation and Develop...
# 4298                       Department of Transportation
# 4299                       Department of Transportation
# 4300                       Department of Transportation
# 4301                           Department of Sanitation
# 4302  Department of Housing Preservation and Develop...
# 4303                       Department of Transportation
# 4304                       Department of Transportation
# 4305                       Department of Transportation
# 4306                       Department of Transportation
# 4307                       Department of Transportation
# 4308  Department of Housing Preservation and Develop...
# 4309             Department of Environmental Protection
# 4310                       Department of Transportation
# 4311                       Department of Transportation
# 4312                       Department of Transportation
# 4313  Department of Housing Preservation and Develop...
# 4314                                 Condo or CoOp Unit
# 4315                       Department of Transportation
# 4316                       Department of Transportation
# 4317                                           Bronx 05
# 4318                       Department of Transportation
# 4319                       Department of Transportation
# 4320                       Department of Transportation
# 4321                                 Condo or CoOp Unit
# 4322                 Department of Parks and Recreation
# 4323                       Department of Transportation
# 4324                           Department for the Aging
# 4325                       Department of Transportation
# 4326  Department of Housing Preservation and Develop...
#
#                       Complaint Type  \
# 0           Traffic Signal Condition
# 1             Street Light Condition
# 2           Traffic Signal Condition
# 3             Street Light Condition
# 4           Benefit Card Replacement
# 5           Traffic Signal Condition
# 6            Maintenance or Facility
# 7                   Street Condition
# 8           Benefit Card Replacement
# 9             Street Light Condition
# 10          Traffic Signal Condition
# 11          Benefit Card Replacement
# 12          Benefit Card Replacement
# 13          Traffic Signal Condition
# 14            Street Light Condition
# 15          Benefit Card Replacement
# 16            Street Light Condition
# 17               Noise - Residential
# 18            Street Light Condition
# 19                             Sewer
# 20           Violation of Park Rules
# 21          Benefit Card Replacement
# 22            Street Light Condition
# 23            Street Light Condition
# 24                      Damaged Tree
# 25          Traffic Signal Condition
# 26            Street Light Condition
# 27            Street Light Condition
# 28            Street Light Condition
# 29          Traffic Signal Condition
# ...                              ...
# 4297          HPD Literature Request
# 4298                Street Condition
# 4299        Traffic Signal Condition
# 4300          Street Light Condition
# 4301                        Graffiti
# 4302          HPD Literature Request
# 4303          Street Light Condition
# 4304          Street Light Condition
# 4305          Street Light Condition
# 4306        Traffic Signal Condition
# 4307        Traffic Signal Condition
# 4308          HPD Literature Request
# 4309                    Water System
# 4310                Street Condition
# 4311        Traffic Signal Condition
# 4312        Traffic Signal Condition
# 4313          HPD Literature Request
# 4314  DOF Property - Reduction Issue
# 4315          Street Light Condition
# 4316          Street Light Condition
# 4317            Sanitation Condition
# 4318               Highway Condition
# 4319          Street Light Condition
# 4320        Traffic Signal Condition
# 4321  DOF Property - Reduction Issue
# 4322         Maintenance or Facility
# 4323          Street Light Condition
# 4324     Housing - Low Income Senior
# 4325        Traffic Signal Condition
# 4326          HPD Literature Request
#
#                                             Descriptor  \
# 0                                      Veh Signal Head
# 1                                     Street Light Out
# 2                                           Controller
# 3                                     Street Light Out
# 4                                             Medicaid
# 5                                           Controller
# 6                                  Structure - Indoors
# 7                                              Pothole
# 8                                             Medicaid
# 9                                     Street Light Out
# 10                                         Push Button
# 11                                          Food Stamp
# 12                                            Medicaid
# 13                                          Controller
# 14                                    Street Light Out
# 15                                            Medicaid
# 16                             Street Light Dayburning
# 17                                    Loud Music/Party
# 18                                    Street Light Out
# 19    Catch Basin Clogged/Flooding (Use Comments) (SC)
# 20                                  Unlicensed Vendors
# 21                                            Medicaid
# 22                                    Street Light Out
# 23                                Street Light Cycling
# 24                         Entire Tree Has Fallen Down
# 25                                          Controller
# 26                                    Street Light Out
# 27                          Multiple Street Lights Out
# 28                                Street Light Cycling
# 29                                          Controller
# ...                                                ...
# 4297                               The ABCs of Housing
# 4298                                           Pothole
# 4299                                         LED Lense
# 4300                                  Street Light Out
# 4301                                          Graffiti
# 4302                               The ABCs of Housing
# 4303                       Fixture/Luminaire Door Open
# 4304                                  Street Light Out
# 4305                            Time Clock Maladjusted
# 4306                                        Controller
# 4307                                Ped Multiple Lamps
# 4308                               The ABCs of Housing
# 4309                         Leak (Use Comments) (WA2)
# 4310                                           Cave-in
# 4311                               Warning Signal Lamp
# 4312                                              Post
# 4313                     The ABCs of Housing - Spanish
# 4314                          Condo or Co-op Abatement
# 4315                                  Street Light Out
# 4316                                  Street Light Out
# 4317                                   12 Dead Animals
# 4318                                            Litter
# 4319                                  Street Light Out
# 4320                               LED Pedestrian Unit
# 4321                          Condo or Co-op Abatement
# 4322                              Structure - Outdoors
# 4323                 Fixture/Luminaire Out Of Position
# 4324                                               NaN
# 4325                                        Controller
# 4326                               The ABCs of Housing
#
#                    Location Type Incident Zip     Incident Address  \
# 0                            NaN          NaN                  NaN
# 1                            NaN          NaN                  NaN
# 2                            NaN          NaN                  NaN
# 3                            NaN          NaN   50 BRONX RIVER AVE
# 4             NYC Street Address          NaN                  NaN
# 5                            NaN          NaN                  NaN
# 6                           Park        11365                  NaN
# 7                            NaN        10451     EAST  153 STREET
# 8             NYC Street Address          NaN                  NaN
# 9                            NaN          NaN  WASHINGTON SQR PARK
# 10                           NaN          NaN                  NaN
# 11            NYC Street Address          NaN                  NaN
# 12        Address Outside of NYC          NaN                  NaN
# 13                           NaN          NaN                  NaN
# 14                           NaN          NaN                  NaN
# 15            NYC Street Address          NaN                  NaN
# 16                           NaN          NaN          424 42 ST W
# 17    Residential Building/House        11418      HILLSIDE AVENUE
# 18                           NaN          NaN                  NaN
# 19                           NaN          NaN                  NaN
# 20                          Park        11375                  NaN
# 21            NYC Street Address          NaN                  NaN
# 22                           NaN          NaN                  NaN
# 23                           NaN          NaN         MULLALY PARK
# 24                          Park        11360                  NaN
# 25                           NaN          NaN                  NaN
# 26                           NaN          NaN                  NaN
# 27                           NaN          NaN       RIVERSIDE PARK
# 28                           NaN          NaN  WILLIAMSBRIDGE OVAL
# 29                           NaN          NaN                  NaN
# ...                          ...          ...                  ...
# 4297                         NaN          NaN                  NaN
# 4298                         NaN          NaN                  NaN
# 4299                         NaN          NaN                  NaN
# 4300                         NaN          NaN                  NaN
# 4301                         NaN          NaN         334 ridge st
# 4302                         NaN          NaN                  NaN
# 4303                         NaN          NaN                  NaN
# 4304                         NaN          NaN                  NaN
# 4305                         NaN          NaN                  NaN
# 4306                         NaN          NaN                  NaN
# 4307                         NaN          NaN                  NaN
# 4308                         NaN          NaN                  NaN
# 4309                         NaN        10128     EAST   88 STREET
# 4310                      Street        11224       WEST 24 STREET
# 4311                         NaN          NaN                  NaN
# 4312                         NaN          NaN                  NaN
# 4313                         NaN          NaN                  NaN
# 4314                  Co-Op Unit        11235                  NaN
# 4315                         NaN          NaN                  NaN
# 4316                         NaN          NaN                  NaN
# 4317                    Sidewalk          NaN                  NaN
# 4318                     Highway          NaN                  NaN
# 4319                         NaN          NaN                  NaN
# 4320                         NaN          NaN                  NaN
# 4321                  Co-Op Unit        10040                  NaN
# 4322                        Park        11375                  NaN
# 4323                         NaN          NaN                  NaN
# 4324              Senior Address        11225                  NaN
# 4325                         NaN          NaN                  NaN
# 4326                         NaN          NaN                  NaN
#
#            ...        Road Ramp  \
# 0          ...              NaN
# 1          ...              NaN
# 2          ...              NaN
# 3          ...              NaN
# 4          ...              NaN
# 5          ...              NaN
# 6          ...              NaN
# 7          ...              NaN
# 8          ...              NaN
# 9          ...              NaN
# 10         ...              NaN
# 11         ...              NaN
# 12         ...              NaN
# 13         ...              NaN
# 14         ...              NaN
# 15         ...              NaN
# 16         ...              NaN
# 17         ...              NaN
# 18         ...              NaN
# 19         ...              NaN
# 20         ...              NaN
# 21         ...              NaN
# 22         ...              NaN
# 23         ...              NaN
# 24         ...              NaN
# 25         ...              NaN
# 26         ...              NaN
# 27         ...              NaN
# 28         ...              NaN
# 29         ...              NaN
# ...        ...              ...
# 4297       ...              NaN
# 4298       ...              NaN
# 4299       ...              NaN
# 4300       ...              NaN
# 4301       ...              NaN
# 4302       ...              NaN
# 4303       ...              NaN
# 4304       ...              NaN
# 4305       ...              NaN
# 4306       ...              NaN
# 4307       ...              NaN
# 4308       ...              NaN
# 4309       ...              NaN
# 4310       ...              NaN
# 4311       ...              NaN
# 4312       ...              NaN
# 4313       ...              NaN
# 4314       ...              NaN
# 4315       ...              NaN
# 4316       ...              NaN
# 4317       ...              NaN
# 4318       ...          Roadway
# 4319       ...              NaN
# 4320       ...              NaN
# 4321       ...              NaN
# 4322       ...              NaN
# 4323       ...              NaN
# 4324       ...              NaN
# 4325       ...              NaN
# 4326       ...              NaN
#
#                                  Bridge Highway Segment Latitude Longitude  \
# 0                                                   NaN      NaN       NaN
# 1                                                   NaN      NaN       NaN
# 2                                                   NaN      NaN       NaN
# 3                                                   NaN      NaN       NaN
# 4                                                   NaN      NaN       NaN
# 5                                                   NaN      NaN       NaN
# 6                                                   NaN      NaN       NaN
# 7                                                   NaN      NaN       NaN
# 8                                                   NaN      NaN       NaN
# 9                                                   NaN      NaN       NaN
# 10                                                  NaN      NaN       NaN
# 11                                                  NaN      NaN       NaN
# 12                                                  NaN      NaN       NaN
# 13                                                  NaN      NaN       NaN
# 14                                                  NaN      NaN       NaN
# 15                                                  NaN      NaN       NaN
# 16                                                  NaN      NaN       NaN
# 17                                                  NaN      NaN       NaN
# 18                                                  NaN      NaN       NaN
# 19                                                  NaN      NaN       NaN
# 20                                                  NaN      NaN       NaN
# 21                                                  NaN      NaN       NaN
# 22                                                  NaN      NaN       NaN
# 23                                                  NaN      NaN       NaN
# 24                                                  NaN      NaN       NaN
# 25                                                  NaN      NaN       NaN
# 26                                                  NaN      NaN       NaN
# 27                                                  NaN      NaN       NaN
# 28                                                  NaN      NaN       NaN
# 29                                                  NaN      NaN       NaN
# ...                                                 ...      ...       ...
# 4297                                                NaN      NaN       NaN
# 4298                                                NaN      NaN       NaN
# 4299                                                NaN      NaN       NaN
# 4300                                                NaN      NaN       NaN
# 4301                                                NaN      NaN       NaN
# 4302                                                NaN      NaN       NaN
# 4303                                                NaN      NaN       NaN
# 4304                                                NaN      NaN       NaN
# 4305                                                NaN      NaN       NaN
# 4306                                                NaN      NaN       NaN
# 4307                                                NaN      NaN       NaN
# 4308                                                NaN      NaN       NaN
# 4309                                                NaN      NaN       NaN
# 4310                                                NaN      NaN       NaN
# 4311                                                NaN      NaN       NaN
# 4312                                                NaN      NaN       NaN
# 4313                                                NaN      NaN       NaN
# 4314                                                NaN      NaN       NaN
# 4315                                                NaN      NaN       NaN
# 4316                                                NaN      NaN       NaN
# 4317                                                NaN      NaN       NaN
# 4318  Entrance Throgs Neck Expwy - Lafayette Ave / C...      NaN       NaN
# 4319                                                NaN      NaN       NaN
# 4320                                                NaN      NaN       NaN
# 4321                                                NaN      NaN       NaN
# 4322                                                NaN      NaN       NaN
# 4323                                                NaN      NaN       NaN
# 4324                                                NaN      NaN       NaN
# 4325                                                NaN      NaN       NaN
# 4326                                                NaN      NaN       NaN
#
#      Location Zip Codes Community Districts  Borough Boundaries  \
# 0         NaN       NaN                 NaN                 NaN
# 1         NaN       NaN                 NaN                 NaN
# 2         NaN       NaN                 NaN                 NaN
# 3         NaN       NaN                 NaN                 NaN
# 4         NaN       NaN                 NaN                 NaN
# 5         NaN       NaN                 NaN                 NaN
# 6         NaN       NaN                 NaN                 NaN
# 7         NaN       NaN                 NaN                 NaN
# 8         NaN       NaN                 NaN                 NaN
# 9         NaN       NaN                 NaN                 NaN
# 10        NaN       NaN                 NaN                 NaN
# 11        NaN       NaN                 NaN                 NaN
# 12        NaN       NaN                 NaN                 NaN
# 13        NaN       NaN                 NaN                 NaN
# 14        NaN       NaN                 NaN                 NaN
# 15        NaN       NaN                 NaN                 NaN
# 16        NaN       NaN                 NaN                 NaN
# 17        NaN       NaN                 NaN                 NaN
# 18        NaN       NaN                 NaN                 NaN
# 19        NaN       NaN                 NaN                 NaN
# 20        NaN       NaN                 NaN                 NaN
# 21        NaN       NaN                 NaN                 NaN
# 22        NaN       NaN                 NaN                 NaN
# 23        NaN       NaN                 NaN                 NaN
# 24        NaN       NaN                 NaN                 NaN
# 25        NaN       NaN                 NaN                 NaN
# 26        NaN       NaN                 NaN                 NaN
# 27        NaN       NaN                 NaN                 NaN
# 28        NaN       NaN                 NaN                 NaN
# 29        NaN       NaN                 NaN                 NaN
# ...       ...       ...                 ...                 ...
# 4297      NaN       NaN                 NaN                 NaN
# 4298      NaN       NaN                 NaN                 NaN
# 4299      NaN       NaN                 NaN                 NaN
# 4300      NaN       NaN                 NaN                 NaN
# 4301      NaN       NaN                 NaN                 NaN
# 4302      NaN       NaN                 NaN                 NaN
# 4303      NaN       NaN                 NaN                 NaN
# 4304      NaN       NaN                 NaN                 NaN
# 4305      NaN       NaN                 NaN                 NaN
# 4306      NaN       NaN                 NaN                 NaN
# 4307      NaN       NaN                 NaN                 NaN
# 4308      NaN       NaN                 NaN                 NaN
# 4309      NaN       NaN                 NaN                 NaN
# 4310      NaN       NaN                 NaN                 NaN
# 4311      NaN       NaN                 NaN                 NaN
# 4312      NaN       NaN                 NaN                 NaN
# 4313      NaN       NaN                 NaN                 NaN
# 4314      NaN       NaN                 NaN                 NaN
# 4315      NaN       NaN                 NaN                 NaN
# 4316      NaN       NaN                 NaN                 NaN
# 4317      NaN       NaN                 NaN                 NaN
# 4318      NaN       NaN                 NaN                 NaN
# 4319      NaN       NaN                 NaN                 NaN
# 4320      NaN       NaN                 NaN                 NaN
# 4321      NaN       NaN                 NaN                 NaN
# 4322      NaN       NaN                 NaN                 NaN
# 4323      NaN       NaN                 NaN                 NaN
# 4324      NaN       NaN                 NaN                 NaN
# 4325      NaN       NaN                 NaN                 NaN
# 4326      NaN       NaN                 NaN                 NaN
#
#      City Council Districts Police Precincts
# 0                       NaN              NaN
# 1                       NaN              NaN
# 2                       NaN              NaN
# 3                       NaN              NaN
# 4                       NaN              NaN
# 5                       NaN              NaN
# 6                       NaN              NaN
# 7                       NaN              NaN
# 8                       NaN              NaN
# 9                       NaN              NaN
# 10                      NaN              NaN
# 11                      NaN              NaN
# 12                      NaN              NaN
# 13                      NaN              NaN
# 14                      NaN              NaN
# 15                      NaN              NaN
# 16                      NaN              NaN
# 17                      NaN              NaN
# 18                      NaN              NaN
# 19                      NaN              NaN
# 20                      NaN              NaN
# 21                      NaN              NaN
# 22                      NaN              NaN
# 23                      NaN              NaN
# 24                      NaN              NaN
# 25                      NaN              NaN
# 26                      NaN              NaN
# 27                      NaN              NaN
# 28                      NaN              NaN
# 29                      NaN              NaN
# ...                     ...              ...
# 4297                    NaN              NaN
# 4298                    NaN              NaN
# 4299                    NaN              NaN
# 4300                    NaN              NaN
# 4301                    NaN              NaN
# 4302                    NaN              NaN
# 4303                    NaN              NaN
# 4304                    NaN              NaN
# 4305                    NaN              NaN
# 4306                    NaN              NaN
# 4307                    NaN              NaN
# 4308                    NaN              NaN
# 4309                    NaN              NaN
# 4310                    NaN              NaN
# 4311                    NaN              NaN
# 4312                    NaN              NaN
# 4313                    NaN              NaN
# 4314                    NaN              NaN
# 4315                    NaN              NaN
# 4316                    NaN              NaN
# 4317                    NaN              NaN
# 4318                    NaN              NaN
# 4319                    NaN              NaN
# 4320                    NaN              NaN
# 4321                    NaN              NaN
# 4322                    NaN              NaN
# 4323                    NaN              NaN
# 4324                    NaN              NaN
# 4325                    NaN              NaN
# 4326                    NaN              NaN
#
# [4327 rows x 46 columns]

# %%
df.iloc[0][0]
# Out:
# 30688456

# %%
df.iloc[1][3]
# Out:
# 'DOT'

# %%
# Convert to numpy.ndarray

# %%
df.as_matrix()
# Out:
# array([[30688456, '05/24/2015 09:02:00 AM', '05/24/2015 09:55:00 AM',
#         ..., nan, nan, nan],
#        [38676721, '03/12/2018 09:56:00 AM', '03/09/2018 11:10:00 PM',
#         ..., nan, nan, nan],
#        [30688451, '05/24/2015 07:00:00 PM', '05/24/2015 08:20:00 PM',
#         ..., nan, nan, nan],
#        ...,
#        [40757271, '11/06/2018 01:05:58 PM', '11/08/2018 10:59:25 AM',
#         ..., nan, nan, nan],
#        [38895615, '04/09/2018 11:42:00 PM', '04/10/2018 12:15:00 AM',
#         ..., nan, nan, nan],
#        [30717793, '05/28/2015 11:55:29 AM', '06/02/2015 11:02:25 AM',
#         ..., nan, nan, nan]], dtype=object)

# %%
# Some Valuable References 
"""
# Python tutorial (offcial document)
https://docs.python.org/3/tutorial/

#The Python Standard Library:
https://docs.python.org/3.5/library/index.html

# Numpy offical document
http://www.numpy.org

# Pandas official document
https://pandas.pydata.org

# Pandas-Cookbook in python (a lot of good example in jupyter)
https://nbviewer.jupyter.org/github/jvns/pandas-cookbook/tree/master/
"""
pass
